# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure, Figure
from bokeh.models import ColumnDataSource, Slider, CustomJS
from bokeh.layouts import layout
import numpy as np

output_notebook()

x = np.sort(np.random.uniform(0, 100, 2000))
y = np.sin(x*10) + np.random.normal(scale=0.1, size=2000)
fig = Figure(plot_height=400)

mask = (x > 0) & (x < 2)

source1 = ColumnDataSource(data={"x":x[mask], "y":y[mask]}, id="source1")
source2 = ColumnDataSource(data={"x":x, "y":y}, id="source2")
line = fig.line(x="x", y="y", source=source1)

callback = CustomJS(args=dict(s1=source1, s2=source2), code="""
var d1 = s1.get("data");
var d2 = s2.get("data");
var start = cb_obj.get("value");
var s = Bokeh._.findIndex(d2["x"], function(v){return v > start;});
var e = Bokeh._.findIndex(d2["x"], function(v){return v > start + 2;});
d1["x"] = [];
d1["y"] = [];
for(i=s;i<=e;i++){
    d1["x"].push(d2["x"][i]);
    d1["y"].push(d2["y"][i]);
}
s1.trigger("change");
""")
slider = Slider(start=0, end=100, step=2, callback=callback)
show(layout(slider, fig))
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a08d84f4-d039-4c4b-8963-2409c04288c3">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-64033d6fc7f0> in <module>()
#      32 """)
#      33 slider = Slider(start=0, end=100, step=2, callback=callback)
# ---> 34 show(layout(slider, fig))
#
# ~/anaconda3/envs/django_env/lib/python3.6/site-packages/bokeh/layouts.py in layout(*args, **kwargs)
#     252     for r in children:
#     253         row_children = []
# --> 254         for item in r:
#     255             if isinstance(item, LayoutDOM):
#     256                 item.sizing_mode = sizing_mode
#
# TypeError: 'Slider' object is not iterable
